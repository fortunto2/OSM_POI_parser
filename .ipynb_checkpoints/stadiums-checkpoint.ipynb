# %%
from imposm.parser import OSMParser
import json

SRC_FILENAME = 'central-fed-district-latest.osm.pbf'
SRC_FILENAME = 'crimean-fed-district-latest.osm.pbf'

# %%
# simple class that handles the parsed OSM data.
class StadiumCounter(object):
    stadium = 0
    
    def nodes(self, nodes):

        for id, tags, (lon, lat) in nodes:
            if 'leisure' in tags:
                if 'stadium' in tags['leisure']:
                    if len(tags)>4:
                      self.stadium += 1
                      print('----------------node--------------------------')
                      print (json.dumps(tags, indent=4, sort_keys=True, ensure_ascii=False))

    def ways(self, ways):
    
        for osmid, tags, refs in ways:
            if 'leisure' in tags:
                if 'stadium' in tags['leisure']:
                    if len(tags)>4:
                      self.stadium += 1
                      print('----------------ways------------------------')
                      print (json.dumps(osmid, indent=4, sort_keys=True, ensure_ascii=False))
                      print (json.dumps(tags, indent=4, sort_keys=True, ensure_ascii=False))
                        
    def coords(self, coords):
        for (osm_id, lon, lat) in coords:
            if osm_id in nodes_ids:
                lon = int(lon + 1000) - 1000
                lat = int(lat + 1000) - 1000
                nodes_counts[(lon, lat)] += 1


# instantiate counter and parser and start parsing
counter = StadiumCounter()
p = OSMParser(concurrency=4, 
              ways_callback=counter.ways,  
#                nodes_callback=counter.nodes,
              coords_callback=counter.coords
             )
p.parse(SRC_FILENAME)

# p = OSMParser(concurrency=4, coords_callback=count_coords)
# p.parse(SRC_FILENAME)

# done
print counter.stadium
# Out:
# ----------------ways------------------------
# 96552984
# {
#     "addr:city": "Гвардейское",
#     "addr:street": "Стадионная улица",
#     "leisure": "stadium",
#     "name": "ФК Гвардеец",
#     "source": "Bing",
#     "sport": "soccer"
# }
# ----------------ways------------------------
# 88507600
# {
#     "leisure": "stadium",
#     "name": "Локомотив",
#     "name:de": "RSC Lokomotiv Stadion",
#     "wikidata": "Q2094801",
#     "wikipedia": "ru:Локомотив (стадион, Симферополь)"
# }
# ----------------ways------------------------
# 90760130
# {
#     "leisure": "stadium",
#     "name": "Стадион «Дружба»",
#     "name:ru": "Стадион «Дружба»",
#     "name:uk": "Стадіон «Дружба»",
#     "wikidata": "Q4168741",
#     "wikipedia": "ru:Дружба (стадион, Бахчисарай)"
# }
# ----------------ways------------------------
# 179248584
# {
#     "barrier": "wall",
#     "leisure": "stadium",
#     "name": "Стадион имени Владимира Шайдерова",
#     "name:ru": "Стадион имени Владимира Шайдерова",
#     "old_name": "Кристалл"
# }
# ----------------ways------------------------
# 224331079
# {
#     "addr:housenumber": "2А",
#     "leisure": "stadium",
#     "name": "Авангард",
#     "phone": "+380 (0654) 260633",
#     "sport": "multi"
# }
# ----------------ways------------------------
# 462047381
# {
#     "barrier": "fence",
#     "leisure": "stadium",
#     "name": "Авангард",
#     "name:ru": "Авангард",
#     "sport": "soccer"
# }
# 6

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

'''
Simple script to create geojson from osm files.
Prints geojson features line by line.
Currently we don't support relations.
Requires (unmodified) imposm and imposm.parser
Inspired by https://github.com/emka/OSMCouch
'''

from multiprocessing import JoinableQueue
from imposm.parser import OSMParser
from imposm.reader import CacheWriterProcess
from imposm.cache import OSMCache

import sys
import io
import json


def generateCache(filename = SRC_FILENAME):
    cache = OSMCache('.')
    coords_queue = JoinableQueue(512)
    coords_writer = CacheWriterProcess(coords_queue, cache.coords_cache, None, marshaled_data=True)
    coords_writer.start()

    parser = OSMParser(coords_callback=coords_queue.put)

    parser.parse(filename)

    coords_queue.put(None)
    coords_writer.join()
    return cache

class Handler(object):

    def __init__(self, cache, output):
        self.coordsCache = cache.coords_cache(mode='r')
        self.outputFile = io.open(output, mode='w')

    def nodeToGEOJson(self, node):
        id, tags, (lon, lat) = node
        return unicode(json.dumps({ 'id': id, 'type': 'Feature', 'geometry': { 'type': 'Point', 'coordinates': [lon, lat] } , 'properties': tags }, ensure_ascii=False) + '\n')

    def wayToGEOJson(self, way):
        id, tags, nodes = way
        coords = self.coordsCache.get_coords(nodes)
        return unicode(json.dumps({ 'id': id, 'type': 'Feature', 'geometry': { 'type': 'LineString', 'coordinates': coords }, 'properties': tags }, ensure_ascii=False) + '\n')

    def nodes_callback(self, nodes):
        for node in nodes:
            self.outputFile.write(self.nodeToGEOJson(node))
            #self.file.write(self.nodeToGEOJson(node))

    def ways_callback(self, ways):
        for osmid, tags, refs, way in ways:
            if 'leisure' in tags:
                if 'stadium' in tags['leisure']:
                    if len(tags)>4:
                      self.stadium += 1
                      print('---------------------------------------------------')
                      print (json.dumps(osmid, indent=4, sort_keys=True, ensure_ascii=False))
                      print (json.dumps(tags, indent=4, sort_keys=True, ensure_ascii=False))
                      self.outputFile.write(self.wayToGEOJson(way))


def main(filename, output):
    #cache = generateCache(filename)
    cache = OSMCache('.')
    coords_queue = JoinableQueue(512)
    coords_writer = CacheWriterProcess(coords_queue, cache.coords_cache, None, marshaled_data=True)
    coords_writer.start()

    handler = Handler(cache, output)
    parser = OSMParser(coords_callback=coords_queue.put,
#             nodes_callback=handler.nodes_callback,
            ways_callback=handler.ways_callback
            )
    parser.parse(filename)

    coords_queue.put(None)
    coords_writer.join()



main(SRC_FILENAME, 'output.json')
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-40-b7dad0f2a43e> in <module>()
#      85
#      86
# ---> 87 main(SRC_FILENAME, 'output.json')
#
# <ipython-input-40-b7dad0f2a43e> in main(filename, output)
#      73     coords_writer.start()
#      74
# ---> 75     handler = Handler(cache, output)
#      76     parser = OSMParser(coords_callback=coords_queue.put,
#      77 #             nodes_callback=handler.nodes_callback,
#
# <ipython-input-40-b7dad0f2a43e> in __init__(self, cache, output)
#      37
#      38     def __init__(self, cache, output):
# ---> 39         self.coordsCache = cache.coords_cache(mode='r')
#      40         self.outputFile = io.open(output, mode='w')
#      41
#
# /home/rustam/anaconda2/lib/python2.7/site-packages/imposm/cache/osm.pyc in coords_cache(self, mode, estimated_records)
#      41         else:
#      42             coords_db = CoordDB
# ---> 43         return self._x_cache(self.coords_fname, coords_db, mode, estimated_records)
#      44
#      45     def nodes_cache(self, mode='r', estimated_records=None):
#
# /home/rustam/anaconda2/lib/python2.7/site-packages/imposm/cache/osm.pyc in _x_cache(self, x, x_class, mode, estimated_records)
#      66             else:
#      67                 cache.close()
# ---> 68         cache = x_class(x, mode, estimated_records=estimated_records)
#      69         self.caches[x] = mode, cache
#      70
#
# /home/rustam/anaconda2/lib/python2.7/site-packages/imposm/cache/tc.pyx in imposm.cache.tc.DeltaCoordsDB.__init__ (imposm/cache/tc.c:6812)()
#     391 class DeltaCoordsDB(object):
#     392     def __init__(self, filename, mode='w', estimated_records=0, delta_nodes_cache_size=100, delta_nodes_size=6):
# --> 393         self.db = BDB(filename, mode, estimated_records)
#     394         self.mode = mode
#     395         self.delta_nodes = {}
#
# /home/rustam/anaconda2/lib/python2.7/site-packages/imposm/cache/tc.pyx in imposm.cache.tc.BDB.__init__ (imposm/cache/tc.c:1700)()
#     102         tcbdbsetcmpfunc(self.db, tccmpint64, NULL)
#     103         if not tcbdbopen(self.db, filename, _modes[mode]):
# --> 104             raise IOError(tcbdbecode(self.db))
#     105         self._opened = 1
#     106
#
# IOError: 1
